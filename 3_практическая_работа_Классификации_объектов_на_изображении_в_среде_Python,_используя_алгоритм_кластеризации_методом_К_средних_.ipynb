# %% [markdown]
# <a href="https://colab.research.google.com/github/AlisaAlenteva/Metod_i_algoritm_obrab_izobr/blob/main/3_%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%D0%9A%D0%BB%D0%B0%D1%81%D1%81%D0%B8%D1%84%D0%B8%D0%BA%D0%B0%D1%86%D0%B8%D0%B8_%D0%BE%D0%B1%D1%8A%D0%B5%D0%BA%D1%82%D0%BE%D0%B2_%D0%BD%D0%B0_%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B8_%D0%B2_%D1%81%D1%80%D0%B5%D0%B4%D0%B5_Python%2C_%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D1%83%D1%8F_%D0%B0%D0%BB%D0%B3%D0%BE%D1%80%D0%B8%D1%82%D0%BC_%D0%BA%D0%BB%D0%B0%D1%81%D1%82%D0%B5%D1%80%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D0%B8_%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D0%BE%D0%BC_%D0%9A_%D1%81%D1%80%D0%B5%D0%B4%D0%BD%D0%B8%D1%85_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ЗАДАНИЕ 1

# %%
from sklearn.cluster import KMeans
import cv2
import numpy as np
import imutils
import argparse
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
img = cv2.imread('jaba.jpg') # Вводим исходное изображение
print("Img's shape: ", img.shape) # Выводим параметры начального изображения
# Out:
# Img's shape:  (913, 1280, 3)

# %%
img_r = (img / 255.0).reshape(-1,3) # Нормализуем изображение
print("New shape (img_r): ", img_r.shape) # Выводим параметры нормализованного изображения
k_colors = KMeans(n_clusters=2).fit(img_r) # Устанавливаем необходимое количество цветов и запускаем процесс обучения (кластеризации пикселей по группам)
imgC = k_colors.cluster_centers_[k_colors.labels_]
imgC = (np.reshape(imgC, (img.shape))*255).astype(np.uint8) # Возвращаем изображению исходные параметры
print("Compressed image's shape: ", imgC.shape)

data_int = np.arange(0, 256).reshape(16, 16)
data_float = np.linspace(0, 1, 256).reshape(16, 16)

fig, axes = plt.subplots(1, 2)

axes[0].imshow(imutils.resize(img, width=800))
axes[0].set_title('до')

axes[1].imshow(imutils.resize(imgC, width=800))
axes[1].set_title('после')

fig.set_figwidth(12)    #  ширина и
fig.set_figheight(6)    #  высота "Figure"

plt.show()
cv2.imwrite('Compressed_1.jpg', imgC)
# Out:
# New shape (img_r):  (1168640, 3)
# Compressed image's shape:  (913, 1280, 3)
# True

# %%
img_r = (img / 255.0).reshape(-1,3) # Нормализуем изображение
print("New shape (img_r): ", img_r.shape) # Выводим параметры нормализованного изображения
k_colors = KMeans(n_clusters=3).fit(img_r) # Устанавливаем необходимое количество цветов и запускаем процесс обучения (кластеризации пикселей по группам)
imgC = k_colors.cluster_centers_[k_colors.labels_]
imgC = (np.reshape(imgC, (img.shape))*255).astype(np.uint8) # Возвращаем изображению исходные параметры
print("Compressed image's shape: ", imgC.shape)

data_int = np.arange(0, 256).reshape(16, 16)
data_float = np.linspace(0, 1, 256).reshape(16, 16)

fig, axes = plt.subplots(1, 2)

axes[0].imshow(imutils.resize(img, width=800))
axes[0].set_title('до')

axes[1].imshow(imutils.resize(imgC, width=800))
axes[1].set_title('после')

fig.set_figwidth(12)    #  ширина и
fig.set_figheight(6)    #  высота "Figure"

plt.show()
cv2.imwrite('Compressed_2.jpg', imgC)
# Out:
# New shape (img_r):  (1168640, 3)
# Compressed image's shape:  (913, 1280, 3)
# True

# %%
img_r = (img / 255.0).reshape(-1,3) # Нормализуем изображение
print("New shape (img_r): ", img_r.shape) # Выводим параметры нормализованного изображения
k_colors = KMeans(n_clusters=4).fit(img_r) # Устанавливаем необходимое количество цветов и запускаем процесс обучения (кластеризации пикселей по группам)
imgC = k_colors.cluster_centers_[k_colors.labels_]
imgC = (np.reshape(imgC, (img.shape))*255).astype(np.uint8) # Возвращаем изображению исходные параметры
print("Compressed image's shape: ", imgC.shape)

data_int = np.arange(0, 256).reshape(16, 16)
data_float = np.linspace(0, 1, 256).reshape(16, 16)

fig, axes = plt.subplots(1, 2)

axes[0].imshow(imutils.resize(img, width=800))
axes[0].set_title('до')

axes[1].imshow(imutils.resize(imgC, width=800))
axes[1].set_title('после')

fig.set_figwidth(12)    #  ширина и
fig.set_figheight(6)    #  высота "Figure"

plt.show()
cv2.imwrite('Compressed_3.jpg', imgC)
# Out:
# New shape (img_r):  (1168640, 3)
# Compressed image's shape:  (913, 1280, 3)
# True

# %%
img_r = (img / 255.0).reshape(-1,3) # Нормализуем изображение
print("New shape (img_r): ", img_r.shape) # Выводим параметры нормализованного изображения
k_colors = KMeans(n_clusters=8).fit(img_r) # Устанавливаем необходимое количество цветов и запускаем процесс обучения (кластеризации пикселей по группам)
imgC = k_colors.cluster_centers_[k_colors.labels_]
imgC = (np.reshape(imgC, (img.shape))*255).astype(np.uint8) # Возвращаем изображению исходные параметры
print("Compressed image's shape: ", imgC.shape)

data_int = np.arange(0, 256).reshape(16, 16)
data_float = np.linspace(0, 1, 256).reshape(16, 16)

fig, axes = plt.subplots(1, 2)

axes[0].imshow(imutils.resize(img, width=800))
axes[0].set_title('до')

axes[1].imshow(imutils.resize(imgC, width=800))
axes[1].set_title('после')

fig.set_figwidth(12)    #  ширина и
fig.set_figheight(6)    #  высота "Figure"

plt.show()
cv2.imwrite('Compressed_4.jpg', imgC)
# Out:
# New shape (img_r):  (1168640, 3)
# Compressed image's shape:  (913, 1280, 3)
# True

# %%
img_r = (img / 255.0).reshape(-1,3) # Нормализуем изображение
print("New shape (img_r): ", img_r.shape) # Выводим параметры нормализованного изображения
k_colors = KMeans(n_clusters=16).fit(img_r) # Устанавливаем необходимое количество цветов и запускаем процесс обучения (кластеризации пикселей по группам)
imgC = k_colors.cluster_centers_[k_colors.labels_]
imgC = (np.reshape(imgC, (img.shape))*255).astype(np.uint8) # Возвращаем изображению исходные параметры
print("Compressed image's shape: ", imgC.shape)

data_int = np.arange(0, 256).reshape(16, 16)
data_float = np.linspace(0, 1, 256).reshape(16, 16)

fig, axes = plt.subplots(1, 2)

axes[0].imshow(imutils.resize(img, width=800))
axes[0].set_title('до')

axes[1].imshow(imutils.resize(imgC, width=800))
axes[1].set_title('после')

fig.set_figwidth(12)    #  ширина и
fig.set_figheight(6)    #  высота "Figure"

plt.show()
cv2.imwrite('Compressed_5.jpg', imgC)
# Out:
# New shape (img_r):  (1168640, 3)
# Compressed image's shape:  (913, 1280, 3)
# True

# %%
img_r = (img / 255.0).reshape(-1,3) # Нормализуем изображение
print("New shape (img_r): ", img_r.shape) # Выводим параметры нормализованного изображения
k_colors = KMeans(n_clusters=32).fit(img_r) # Устанавливаем необходимое количество цветов и запускаем процесс обучения (кластеризации пикселей по группам)
imgC = k_colors.cluster_centers_[k_colors.labels_]
imgC = (np.reshape(imgC, (img.shape))*255).astype(np.uint8) # Возвращаем изображению исходные параметры
print("Compressed image's shape: ", imgC.shape)

data_int = np.arange(0, 256).reshape(16, 16)
data_float = np.linspace(0, 1, 256).reshape(16, 16)

fig, axes = plt.subplots(1, 2)

axes[0].imshow(imutils.resize(img, width=800))
axes[0].set_title('до')

axes[1].imshow(imutils.resize(imgC, width=800))
axes[1].set_title('после')

fig.set_figwidth(12)    #  ширина и
fig.set_figheight(6)    #  высота "Figure"

plt.show()
cv2.imwrite('Compressed_6.jpg', imgC)
# Out:
# New shape (img_r):  (1168640, 3)
# Compressed image's shape:  (913, 1280, 3)
# True

# %%
img_r = (img / 255.0).reshape(-1,3) # Нормализуем изображение
print("New shape (img_r): ", img_r.shape) # Выводим параметры нормализованного изображения
k_colors = KMeans(n_clusters=64).fit(img_r) # Устанавливаем необходимое количество цветов и запускаем процесс обучения (кластеризации пикселей по группам)
imgC = k_colors.cluster_centers_[k_colors.labels_]
imgC = (np.reshape(imgC, (img.shape))*255).astype(np.uint8) # Возвращаем изображению исходные параметры
print("Compressed image's shape: ", imgC.shape)

data_int = np.arange(0, 256).reshape(16, 16)
data_float = np.linspace(0, 1, 256).reshape(16, 16)

fig, axes = plt.subplots(1, 2)

axes[0].imshow(imutils.resize(img, width=800))
axes[0].set_title('до')

axes[1].imshow(imutils.resize(imgC, width=800))
axes[1].set_title('после')

fig.set_figwidth(12)    #  ширина и
fig.set_figheight(6)    #  высота "Figure"

plt.show()
cv2.imwrite('Compressed_7.jpg', imgC)
# Out:
# New shape (img_r):  (1168640, 3)
# Compressed image's shape:  (913, 1280, 3)
# True

# %%
img_r = (img / 255.0).reshape(-1,3) # Нормализуем изображение
print("New shape (img_r): ", img_r.shape) # Выводим параметры нормализованного изображения
k_colors = KMeans(n_clusters=128).fit(img_r) # Устанавливаем необходимое количество цветов и запускаем процесс обучения (кластеризации пикселей по группам)
imgC = k_colors.cluster_centers_[k_colors.labels_]
imgC = (np.reshape(imgC, (img.shape))*255).astype(np.uint8) # Возвращаем изображению исходные параметры
print("Compressed image's shape: ", imgC.shape)

data_int = np.arange(0, 256).reshape(16, 16)
data_float = np.linspace(0, 1, 256).reshape(16, 16)

fig, axes = plt.subplots(1, 2)

axes[0].imshow(imutils.resize(img, width=800))
axes[0].set_title('до')

axes[1].imshow(imutils.resize(imgC, width=800))
axes[1].set_title('после')

fig.set_figwidth(12)    #  ширина и
fig.set_figheight(6)    #  высота "Figure"

plt.show()
cv2.imwrite('Compressed_8.jpg', imgC)
# Out:
# New shape (img_r):  (1168640, 3)
# Compressed image's shape:  (913, 1280, 3)
# True

# %%
img_r = (img / 255.0).reshape(-1,3) # Нормализуем изображение
print("New shape (img_r): ", img_r.shape) # Выводим параметры нормализованного изображения
k_colors = KMeans(n_clusters=256).fit(img_r) # Устанавливаем необходимое количество цветов и запускаем процесс обучения (кластеризации пикселей по группам)
imgC = k_colors.cluster_centers_[k_colors.labels_]
imgC = (np.reshape(imgC, (img.shape))*255).astype(np.uint8) # Возвращаем изображению исходные параметры
print("Compressed image's shape: ", imgC.shape)

data_int = np.arange(0, 256).reshape(16, 16)
data_float = np.linspace(0, 1, 256).reshape(16, 16)

fig, axes = plt.subplots(1, 2)

axes[0].imshow(imutils.resize(img, width=800))
axes[0].set_title('до')

axes[1].imshow(imutils.resize(imgC, width=800))
axes[1].set_title('после')

fig.set_figwidth(12)    #  ширина и
fig.set_figheight(6)    #  высота "Figure"

plt.show()
cv2.imwrite('Compressed_9.jpg', imgC)
# Out:
# New shape (img_r):  (1168640, 3)
# Compressed image's shape:  (913, 1280, 3)
# True

# %% [markdown]
# # ЗАДАНИЕ 2

# %%
import numpy as np
import matplotlib
from PIL import Image

def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('jaba.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 2 # устанавливаем количество цветов
Max_iters = 10 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('output1.jpeg', "JPEG", optimize = True)
# Out:
# Error = 6058.563696262125
# Error = 2629.516461479495
# Error = 2537.322434307008
# Error = 2519.731768337428
# Error = 2516.2721103785075
# Error = 2515.608902607822
# Error = 2515.474481348958
# Error = 2515.448294665115
# Error = 2515.4439756996594
# Error = 2515.442979582303

# %%
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('jaba.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 3 # устанавливаем количество цветов
Max_iters = 4 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('output2.jpeg', "JPEG", optimize = True)
# Out:
# Error = 1830.949258967679
# Error = 1419.9584550226548
# Error = 1416.518488062478
# Error = 1415.5228896244332

# %%
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('jaba.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 4 # устанавливаем количество цветов
Max_iters = 4 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('output3.jpeg', "JPEG", optimize = True)
# Out:
# Error = 4011.651540251975
# Error = 1435.827270626953
# Error = 1171.3930301289038
# Error = 1089.3549068627044

# %%
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('jaba.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 8 # устанавливаем количество цветов
Max_iters = 4 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('output4.jpeg', "JPEG", optimize = True)
# Out:
# Error = 1235.7097275464955
# Error = 803.6648632622558
# Error = 733.1184507124204
# Error = 699.8669684903309

# %%
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('jaba.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 16 # устанавливаем количество цветов
Max_iters = 3 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('output5.jpeg', "JPEG", optimize = True)
# Out:
# Error = 661.794844434563
# Error = 401.6154133898137
# Error = 367.8713967958237

# %%
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('jaba.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 32 # устанавливаем количество цветов
Max_iters = 2 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('output6.jpeg', "JPEG", optimize = True)
# Out:
# Error = 354.0821673055933
# Error = 246.9691579364589

# %%
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('jaba.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 64 # устанавливаем количество цветов
Max_iters = 2 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('output7.jpeg', "JPEG", optimize = True)
# Out:
# Error = 197.80068541210443
# Error = 152.4770296565628

# %%
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('jaba.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 128 # устанавливаем количество цветов
Max_iters = 2 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('output8.jpeg', "JPEG", optimize = True)
# Out:
# Error = 138.63115416210255
# Error = 103.65573217874238

# %%
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('jaba.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 256 # устанавливаем количество цветов
Max_iters = 2 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('output9.jpeg', "JPEG", optimize = True)
# Out:
# Error = 91.91236736719597
# Error = 68.59111645939852

# %% [markdown]
# # ЗАДАНИЕ 3
#
# ![3 Задание. скрин таблица.png](data:image/png;base64,...)

# %% [markdown]
# # ЗАДАНИЕ 4

# %%
img_1 = cv2.imread('crab.jpg') # Вводим исходное изображение
print("Img's 1 shape: ", img_1.shape) # Выводим параметры начального изображения
img_2 = cv2.imread('krevetka.jpg') # Вводим исходное изображение
print("Img's 2 shape: ", img_2.shape) # Выводим параметры начального изображения
img_3 = cv2.imread('meduza.jpg') # Вводим исходное изображение
print("Img's 3 shape: ", img_3.shape) # Выводим параметры начального изображения
img_4 = cv2.imread('ulitka.jpg') # Вводим исходное изображение
print("Img's 4 shape: ", img_4.shape) # Выводим параметры начального изображения
img_5 = cv2.imread('yacher.jpg') # Вводим исходное изображение
print("Img's 5 shape: ", img_5.shape) # Выводим параметры начального изображения
# Out:
# Img's 1 shape:  (1364, 2060, 3)
# Img's 2 shape:  (1600, 2000, 3)
# Img's 3 shape:  (1200, 1800, 3)
# Img's 4 shape:  (1498, 2247, 3)
# Img's 5 shape:  (1280, 1920, 3)

# %%
from PIL import Image
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('crab.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 128 # устанавливаем количество цветов
Max_iters = 1 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('crab2.jpeg', "JPEG", optimize = True)
# Out:
# Error = 195.67805853714177

# %%
from PIL import Image
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('krevetka.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 128 # устанавливаем количество цветов
Max_iters = 2 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('krevetka2.jpeg', "JPEG", optimize = True)
# Out:
# Error = 183.8571053125041
# Error = 127.83834102258776

# %%
from PIL import Image
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('meduza.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 128 # устанавливаем количество цветов
Max_iters = 2 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('meduza2.jpeg', "JPEG", optimize = True)
# Out:
# Error = 259.80702777777833
# Error = 190.5370224034781

# %%
from PIL import Image
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('ulitka.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 128 # устанавливаем количество цветов
Max_iters = 2 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('ulitka2.jpeg', "JPEG", optimize = True)
# Out:
# Error = 266.7889979994085
# Error = 164.5060560685084

# %%
from PIL import Image
def kmeans(Input,K,Max_iters):
    
    N,D = np.shape(Input)
    R = np.random.permutation(N)
    Kvec = Input[R[0:K],:]
    Distance = np.zeros((N,K))
    
    for nn in range(0,Max_iters):
        F = np.zeros((N,K))
        for kk in range(0,K):
            Distance[:,kk] = np.sum( np.square(Input - np.tile( Kvec[kk,:], (N,1)),dtype=np.float64),axis=1 )
        Dmin = Distance.argmin(axis=1) % Distance.shape[1]
        for mm in range(0,K):
            if np.size(Dmin[mm==Dmin]) >0:
                Kvec[mm,:] = np.mean(Input[mm==Dmin],axis=0)
        for ii in range(0,N):
            F[ii,Dmin[ii]] = 1
        error = sum(sum((F*Distance)/N))
        print('Error = ' + str(error))
    return Kvec,Dmin


Datain = np.asarray(Image.open('yacher.jpg'),dtype=np.float64)

ReshapedData = np.reshape(Datain, (np.size(Datain,0) * np.size(Datain,1),np.size(Datain,2)))

K = 128 # устанавливаем количество цветов
Max_iters = 2 # устанавливаем количество итераций, чем больше итераций, тем тщательнее будет осуществляться кластеризация и тем дольше будет работать программа

Kvec,Dmin = kmeans(ReshapedData,K,Max_iters)

Dvec = np.zeros((len(Dmin),len(Kvec[0,:])))

for jj in range(0,K):
    Dvec[jj==Dmin,:] = Kvec[jj,:]

imout = np.reshape(np.uint8(Dvec), (np.size(Datain,0),np.size(Datain,1),len(Kvec[0,:])))

im = Image.fromarray(imout,'RGB')
im.show()
im.save('yacher.jpeg', "JPEG", optimize = True)
# Out:
# Error = 257.4784676106779
# Error = 167.55781314336534
